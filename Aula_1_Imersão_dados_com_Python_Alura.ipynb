# %% [markdown]
# <a href="https://colab.research.google.com/github/giibudri2228/limpeza-dados-pandas/blob/main/Aula_1_Imers%C3%A3o_dados_com_Python_Alura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1 - Dados com Pandas**

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/guilhermeonrails/data-jobs/refs/heads/main/salaries.csv")

# %%
# Leia as linhas

df.head(10)
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0     2025.0               SE              FT  Solutions Engineer  214000
# 1     2025.0               SE              FT  Solutions Engineer  136000
# 2     2025.0               MI              FT       Data Engineer  158800
# 3     2025.0               MI              FT       Data Engineer  139200
# 4     2025.0               EN              FT       Data Engineer   90000
# 5     2025.0               EN              FT       Data Engineer   80000
# 6     2025.0               SE              FT      Data Scientist  185000
# 7     2025.0               SE              FT      Data Scientist  148000
# 8     2025.0               MI              FT      Data Scientist  135000
# 9     2025.0               MI              FT      Data Scientist  108000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# ...

# %%
# Formato, nome e tipo dos dados

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133349 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           133339 non-null  float64
#  1   experience_level    133349 non-null  object
#  2   employment_type     133349 non-null  object
#  3   job_title           133349 non-null  object
#  4   salary              133349 non-null  int64
#  5   salary_currency     133349 non-null  object
#  6   salary_in_usd       133349 non-null  int64
#  7   employee_residence  133349 non-null  object
#  8   remote_ratio        133349 non-null  int64
#  9   company_location    133349 non-null  object
#  10  company_size        133349 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 11.2+ MB

# %%
# Estatísticas descritivas

df.describe()
# Out:
#            work_year        salary  salary_in_usd   remote_ratio
# count  133339.000000  1.333490e+05  133349.000000  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098      20.905669
# std         0.680627  2.173860e+05   74288.363097      40.590044
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.060200e+05  106000.000000       0.000000
# 50%      2024.000000  1.470000e+05  146206.000000       0.000000
# 75%      2025.000000  1.990000e+05  198000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000

# %%
# Tupla com número de linhas e colunos, respectivamente

df.shape
# Out:
# (133349, 11)

# %%
print(f'Há {df.shape[0]} linhas e {df.shape[1]} colunas! ')
# Out:
# Há 133349 linhas e 11 colunas!

# %% [markdown]
# # Traduzindo para o PT-BR as colunas do DataFrame

# %%
# Nomes das colunas

df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
columns_translation = {
    'work_year': 'ano_trabalho',
    'experience_level': 'nivel_experiencia',
    'employment_type': 'tipo_emprego',
    'job_title': 'titulo_cargo',
    'salary': 'salario',
    'salary_currency': 'moeda_salario',
    'salary_in_usd': 'salario_em_usd',
    'employee_residence': 'residencia_funcionario',
    'remote_ratio': 'proporcao_remoto',
    'company_location': 'localizacao_empresa',
    'company_size': 'tamanho_empresa'
}

''' Renomeando as colunas para o PT-BR '''

df = df.rename(columns=columns_translation)
print(df.columns)
# Out:
# Index(['ano_trabalho', 'nivel_experiencia', 'tipo_emprego', 'titulo_cargo',
#        'salario', 'moeda_salario', 'salario_em_usd', 'residencia_funcionario',
#        'proporcao_remoto', 'localizacao_empresa', 'tamanho_empresa'],
#       dtype='object')

# %% [markdown]
# # Soma dos agrupamentos de cada coluna

# %%
# Agrupa a coluna e soma os resultados

df["nivel_experiencia"].value_counts()
# Out:
# nivel_experiencia
# SE    77241
# MI    40465
# EN    12443
# EX     3200
# Name: count, dtype: int64

# %%
df["tipo_emprego"].value_counts()
# Out:
# tipo_emprego
# FT    132563
# CT       394
# PT       376
# FL        16
# Name: count, dtype: int64

# %%
df["proporcao_remoto"].value_counts()
# Out:
# proporcao_remoto
# 0      105312
# 100     27718
# 50        319
# Name: count, dtype: int64

# %%
nivel_experiencia_translation = {
    'SE': 'Sênior',
    'MI': 'Pleno',
    'EN': 'Júnior',
    'EX': 'Executivo'
}

df['nivel_experiencia'] = df['nivel_experiencia'].replace(nivel_experiencia_translation)

df['nivel_experiencia'].value_counts()
# Out:
# nivel_experiencia
# Sênior       77241
# Pleno        40465
# Júnior       12443
# Executivo     3200
# Name: count, dtype: int64

# %%
tipo_emprego_translation = {
    'FT': 'Tempo Integral',
    'CT': 'Contrato',
    'PT': 'Meio Período',
    'FL': 'Autônomo'
}

df['tipo_emprego'] = df['tipo_emprego'].replace(tipo_emprego_translation)

df['tipo_emprego'].value_counts()
# Out:
# tipo_emprego
# Tempo Integral    132563
# Contrato             394
# Meio Período         376
# Autônomo              16
# Name: count, dtype: int64

# %%
tamanho_empresa_translation = {
    'S': 'Pequena',
    'M': 'Média',
    'L': 'Grande'
}

df['tamanho_empresa'] = df['tamanho_empresa'].replace(tamanho_empresa_translation)

df['tamanho_empresa'].value_counts()
# Out:
# tamanho_empresa
# Média      129561
# Grande       3574
# Pequena       214
# Name: count, dtype: int64

# %%
proporcao_remoto_translation = {
    0: 'Presencial',
    50: 'Híbrido',
    100: 'Totalmente Remoto'
}

df['proporcao_remoto'] = df['proporcao_remoto'].replace(proporcao_remoto_translation)

df['proporcao_remoto'].value_counts()
# Out:
# proporcao_remoto
# Presencial           105312
# Totalmente Remoto     27718
# Híbrido                 319
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    ano_trabalho nivel_experiencia    tipo_emprego        titulo_cargo  \
# 0        2025.0            Sênior  Tempo Integral  Solutions Engineer
# 1        2025.0            Sênior  Tempo Integral  Solutions Engineer
# 2        2025.0             Pleno  Tempo Integral       Data Engineer
# 3        2025.0             Pleno  Tempo Integral       Data Engineer
# 4        2025.0            Júnior  Tempo Integral       Data Engineer
#
#    salario moeda_salario  salario_em_usd residencia_funcionario  \
# 0   214000           USD          214000                     US
# 1   136000           USD          136000                     US
# 2   158800           USD          158800                     AU
# 3   139200           USD          139200                     AU
# 4    90000           USD           90000                     US
#
#     proporcao_remoto localizacao_empresa tamanho_empresa
# 0  Totalmente Remoto                  US           Média
# ...

# %% [markdown]
# # 2 - Limpeza e Preparação de **Dados**

# %%
# Descrição de informações não numéricas

df.describe(include="object")
# Out:
#        nivel_experiencia    tipo_emprego    titulo_cargo moeda_salario  \
# count             133349          133349          133349        133349
# unique                 4               4             390            26
# top               Sênior  Tempo Integral  Data Scientist           USD
# freq               77241          132563           17314        126140
#
#        residencia_funcionario proporcao_remoto localizacao_empresa  \
# count                  133349           133349              133349
# unique                    102                3                  95
# top                        US       Presencial                  US
# freq                   119579           105312              119641
#
#        tamanho_empresa
# count           133349
# unique               3
# top              Média
# freq            129561

# %%
# Saber se há valores nulos (True caso houver)

df.isnull()
# Out:
#         ano_trabalho  nivel_experiencia  tipo_emprego  titulo_cargo  salario  \
# 0              False              False         False         False    False
# 1              False              False         False         False    False
# 2              False              False         False         False    False
# 3              False              False         False         False    False
# 4              False              False         False         False    False
# ...              ...                ...           ...           ...      ...
# 133344         False              False         False         False    False
# 133345         False              False         False         False    False
# 133346         False              False         False         False    False
# 133347         False              False         False         False    False
# 133348         False              False         False         False    False
#
# ...

# %%
# Soma dos nulos

df.isnull().sum()
# Out:
# ano_trabalho              10
# nivel_experiencia          0
# tipo_emprego               0
# titulo_cargo               0
# salario                    0
# moeda_salario              0
# salario_em_usd             0
# residencia_funcionario     0
# proporcao_remoto           0
# localizacao_empresa        0
# tamanho_empresa            0
# dtype: int64

# %%
df["ano_trabalho"].unique()
# Out:
# array([2025.,   nan, 2024., 2022., 2023., 2020., 2021.])

# %%
df[df.isnull().any(axis=1)]
# Out:
#         ano_trabalho nivel_experiencia    tipo_emprego  \
# 5588             NaN            Sênior  Tempo Integral
# 59692            NaN             Pleno  Tempo Integral
# 59710            NaN            Júnior  Tempo Integral
# 59759            NaN            Sênior  Tempo Integral
# 59789            NaN            Sênior  Tempo Integral
# 131000           NaN            Sênior  Tempo Integral
# 131006           NaN            Sênior  Tempo Integral
# 133054           NaN            Júnior  Tempo Integral
# 133281           NaN             Pleno  Tempo Integral
# 133317           NaN             Pleno  Tempo Integral
#
#                      titulo_cargo  salario moeda_salario  salario_em_usd  \
# 5588              Product Manager   184500           USD          184500
# 59692                    Engineer   110000           USD          110000
# 59710              Data Scientist   208800           USD          208800
# ...

# %%
# Completando salários nulos com média e mediana

import numpy as np

''' np.nam -> Valores nulos '''

df_salarios = pd.DataFrame({
    "nome" : ["Ana", "Bruno", "Carlos", "Daniele", "Val"],
    "salario" : [4000, np.nan, 5000, np.nan, 100000]
})


''' Calcula mediana e substitui os nulos pela média '''

df_salarios["salario_media"] = df_salarios['salario'].fillna(df_salarios['salario'].mean().round(2))

''' Calcula mediana e substitui os nulos pela mediana '''

df_salarios["salario_mediana"] = df_salarios['salario'].fillna(df_salarios['salario'].median())

df_salarios
# Out:
#       nome   salario  salario_media  salario_mediana
# 0      Ana    4000.0        4000.00           4000.0
# 1    Bruno       NaN       36333.33           5000.0
# 2   Carlos    5000.0        5000.00           5000.0
# 3  Daniele       NaN       36333.33           5000.0
# 4      Val  100000.0      100000.00         100000.0

# %%
# Preeenchendo temperaturas nulas com ffill -> Completa com o valor anterior

df_temperaturas = pd.DataFrame({
    "dia" : ["Segunda-feira", "Terça-feira", "Quarta-feira", "Quinta-feira", "Sexta-feira"],
    "temperatura" : [30, np.nan, np.nan, 28, 27]
})

df_temperaturas["preenchido_ffill"] = df_temperaturas["temperatura"].ffill()
df_temperaturas
# Out:
#              dia  temperatura  preenchido_ffill
# 0  Segunda-feira         30.0              30.0
# 1    Terça-feira          NaN              30.0
# 2   Quarta-feira          NaN              30.0
# 3   Quinta-feira         28.0              28.0
# 4    Sexta-feira         27.0              27.0

# %%
# Preeenchendo temperaturas nulas com bfill -> Completa com o valor posterior

df_temperaturas = pd.DataFrame({
    "dia" : ["Segunda-feira", "Terça-feira", "Quarta-feira", "Quinta-feira", "Sexta-feira"],
    "temperatura" : [30, np.nan, np.nan, 28, 27]
})

df_temperaturas["preenchido_bfill"] = df_temperaturas["temperatura"].bfill()
df_temperaturas
# Out:
#              dia  temperatura  preenchido_bfill
# 0  Segunda-feira         30.0              30.0
# 1    Terça-feira          NaN              28.0
# 2   Quarta-feira          NaN              28.0
# 3   Quinta-feira         28.0              28.0
# 4    Sexta-feira         27.0              27.0

# %%
# Preenchendo uma nova coluna com "Não informado" onde há valores nulos

df_cidades = pd.DataFrame({
    "nome" : ["Ana", "Bruno", "Carlos", "Daniele", "Val"],
    "cidade" : ["São Paulo", np.nan, "Curitiba", np.nan, "Belém"]
})

df_cidades['cidade_preenchida'] = df_cidades["cidade"].fillna("Não informado")
df_cidades
# Out:
#       nome     cidade cidade_preenchida
# 0      Ana  São Paulo         São Paulo
# 1    Bruno        NaN     Não informado
# 2   Carlos   Curitiba          Curitiba
# 3  Daniele        NaN     Não informado
# 4      Val      Belém             Belém

# %%
# Excluindo valores nulos

df_limpo = df.dropna()

# %%
df_limpo.isnull().sum()
# Out:
# ano_trabalho              0
# nivel_experiencia         0
# tipo_emprego              0
# titulo_cargo              0
# salario                   0
# moeda_salario             0
# salario_em_usd            0
# residencia_funcionario    0
# proporcao_remoto          0
# localizacao_empresa       0
# tamanho_empresa           0
# dtype: int64

# %%
# Dados limpos, sem nulos

df_limpo.isnull().sum()
# Out:
# ano_trabalho              0
# nivel_experiencia         0
# tipo_emprego              0
# titulo_cargo              0
# salario                   0
# moeda_salario             0
# salario_em_usd            0
# residencia_funcionario    0
# proporcao_remoto          0
# localizacao_empresa       0
# tamanho_empresa           0
# dtype: int64

# %%
df_limpo.head()
# Out:
#    ano_trabalho nivel_experiencia    tipo_emprego        titulo_cargo  \
# 0        2025.0            Sênior  Tempo Integral  Solutions Engineer
# 1        2025.0            Sênior  Tempo Integral  Solutions Engineer
# 2        2025.0             Pleno  Tempo Integral       Data Engineer
# 3        2025.0             Pleno  Tempo Integral       Data Engineer
# 4        2025.0            Júnior  Tempo Integral       Data Engineer
#
#    salario moeda_salario  salario_em_usd residencia_funcionario  \
# 0   214000           USD          214000                     US
# 1   136000           USD          136000                     US
# 2   158800           USD          158800                     AU
# 3   139200           USD          139200                     AU
# 4    90000           USD           90000                     US
#
#     proporcao_remoto localizacao_empresa tamanho_empresa
# 0  Totalmente Remoto                  US           Média
# ...

# %%
df_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133339 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   ano_trabalho            133339 non-null  float64
#  1   nivel_experiencia       133339 non-null  object
#  2   tipo_emprego            133339 non-null  object
#  3   titulo_cargo            133339 non-null  object
#  4   salario                 133339 non-null  int64
#  5   moeda_salario           133339 non-null  object
#  6   salario_em_usd          133339 non-null  int64
#  7   residencia_funcionario  133339 non-null  object
#  8   proporcao_remoto        133339 non-null  object
#  9   localizacao_empresa     133339 non-null  object
#  10  tamanho_empresa         133339 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 12.2+ MB

# %%
# Mudando o tipo de dado

''' Mudamos o ano para um valor inteiro e não decimal (float) '''

df_limpo = df_limpo.assign(ano_trabalho=df_limpo['ano_trabalho'].astype('int64'))
df_limpo
# Out:
#         ano_trabalho nivel_experiencia    tipo_emprego  \
# 0               2025            Sênior  Tempo Integral
# 1               2025            Sênior  Tempo Integral
# 2               2025             Pleno  Tempo Integral
# 3               2025             Pleno  Tempo Integral
# 4               2025            Júnior  Tempo Integral
# ...              ...               ...             ...
# 133344          2020            Sênior  Tempo Integral
# 133345          2021             Pleno  Tempo Integral
# 133346          2020            Júnior  Tempo Integral
# 133347          2020            Júnior        Contrato
# 133348          2021            Sênior  Tempo Integral
#
#                     titulo_cargo  salario moeda_salario  salario_em_usd  \
# 0             Solutions Engineer   214000           USD          214000
# 1             Solutions Engineer   136000           USD          136000
# 2                  Data Engineer   158800           USD          158800
# ...

# %% [markdown]
# #3 - Visualização de **dados**

# %%
df_limpo.head()
# Out:
#    ano_trabalho nivel_experiencia    tipo_emprego        titulo_cargo  \
# 0          2025            Sênior  Tempo Integral  Solutions Engineer
# 1          2025            Sênior  Tempo Integral  Solutions Engineer
# 2          2025             Pleno  Tempo Integral       Data Engineer
# 3          2025             Pleno  Tempo Integral       Data Engineer
# 4          2025            Júnior  Tempo Integral       Data Engineer
#
#    salario moeda_salario  salario_em_usd residencia_funcionario  \
# 0   214000           USD          214000                     US
# 1   136000           USD          136000                     US
# 2   158800           USD          158800                     AU
# 3   139200           USD          139200                     AU
# 4    90000           USD           90000                     US
#
#     proporcao_remoto localizacao_empresa tamanho_empresa
# 0  Totalmente Remoto                  US           Média
# ...

# %%
# Gráfico com a biblioteca Pandas

''' Acessando uma coluna '''

df_limpo['nivel_experiencia'].value_counts().plot(kind='bar', title='Distribuição de senioridade')
# Out:
# <Axes: title={'center': 'Distribuição de senioridade'}, xlabel='nivel_experiencia'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Criando o primeiro gráfico

sns.barplot(data=df_limpo, x='nivel_experiencia', y='salario_em_usd')
# Out:
# <Axes: xlabel='nivel_experiencia', ylabel='salario_em_usd'>

# %%
# Melhorando a visualização do gráfico

plt.figure(figsize=(8, 5))
sns.barplot(data=df_limpo, x='nivel_experiencia', y='salario_em_usd')
plt
plt.title('Salário médio por nível de experiência')
plt
plt.xlabel('Nível de experiência')
plt
plt.ylabel('Salário médio anul (USD)')
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py'>

# %%
# Criando a variável "ordem" MAIOR-MENOR

df_limpo.groupby('nivel_experiencia')['salario_em_usd'].mean().sort_values(ascending=False)
ordem = df_limpo.groupby('nivel_experiencia')['salario_em_usd'].mean().sort_values(ascending=False).index

# %%
ordem = df_limpo.groupby('nivel_experiencia')['salario_em_usd'].mean().sort_values(ascending=False).index

# %%
# Index = Pega o nome de cada uma das linhas e cria uma lista contendo a ordem corretamente

ordem
# Out:
# Index(['Executivo', 'Sênior', 'Pleno', 'Júnior'], dtype='object', name='nivel_experiencia')

# %%
# Deixando o gráfico em ordem MAIOR-MENOR

''' Adicionando o parâmetro ORDER que recebe a variável ORDEM '''

plt.figure(figsize=(8, 5))
sns.barplot(data=df_limpo, x='nivel_experiencia', y='salario_em_usd', order=ordem)
plt
plt.title('Salário médio por nível de experiência')
plt
plt.xlabel('Nível de experiência')
plt
plt.ylabel('Salário médio anul (USD)')
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py'>

# %% [markdown]
# # Histrograma sobre distribuição salarial

# %%
# Histograma

''' Valores indo de 50 a 50 = bins '''

''' KDE = Desenho de como as barras estão distribuidas '''

plt.figure(figsize=(10, 5))
sns.histplot(df_limpo['salario_em_usd'], bins = 50, kde=True)
plt.title('Distribuição salarial')
plt.xlabel('Salário anual (USD)')
plt.ylabel('Frequência')
plt.show()

# %%
# Gráfico em Boxplot -> Técnico


plt.figure(figsize=(8, 5))
sns.boxplot(data=df_limpo['salario_em_usd'])
plt.title('Distribuição salarial')
plt.xlabel('Salário anual (USD)')
plt.show()

# %% [markdown]
# # Gráfico Técnico sobre Distribução salarial entre os níveis de senioridade

# %%
ordem_senioridade = ['Júnior','Pleno', 'Sênior','Executivo']

plt.figure(figsize=(8, 5))
sns.boxplot(x='nivel_experiencia', y='salario_em_usd', data=df_limpo, order=ordem_senioridade, palette='Set2', hue='nivel_experiencia')
plt.title('Distribuição salarial')
plt.xlabel('Senioridade')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Recalculando a ordem caso a variável não esteja disponível no ambiente atual
# ou para garantir que a ordem é a correta baseada nos dados atuais de df_limpo.
# Se a célula anterior que define 'ordem' já foi executada, esta linha é redundante mas segura.
ordem = df_limpo.groupby('nivel_experiencia')['salario_em_usd'].mean().sort_values(ascending=False).index

plt.figure(figsize=(8, 5))
sns.barplot(data=df_limpo, x='nivel_experiencia', y='salario_em_usd', order=ordem, palette='viridis')
plt.title('Salário Médio por Nível de Experiência')
plt.xlabel('Nível de Experiência')
plt.ylabel('Salário Médio Anual (USD)')
plt.show()
# Out:
# /tmp/ipython-input-2634192129.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_limpo, x='nivel_experiencia', y='salario_em_usd', order=ordem, palette='viridis')

# %% [markdown]
# # Media Salarial por Nível de Senioridade

# %%
#Utilizando o plotly

import plotly.express as px

# Calculate the average salary per experience level
df_salario_por_senioridade = df_limpo.groupby('nivel_experiencia')['salario_em_usd'].mean().reset_index()

# Define the order for seniority levels
ordem_senioridade = ['Júnior', 'Pleno', 'Sênior', 'Executivo']

# Create the bar chart using Plotly Express
fig = px.bar(
    df_salario_por_senioridade,
    x='nivel_experiencia',
    y='salario_em_usd',
    title='Média Salarial por Nível de Senioridade (USD)',
    labels={
        'nivel_experiencia': 'Nível de Experiência',
        'salario_em_usd': 'Média Salarial Anual (USD)'
    },
    category_orders={'nivel_experiencia': ordem_senioridade},
    color='nivel_experiencia', # Color bars by seniority level
    color_discrete_sequence=px.colors.qualitative.Set2 # Choose a color sequence
)

# Update layout for better readability
fig.update_layout(xaxis_title='Nível de Experiência', yaxis_title='Média Salarial Anual (USD)')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Gráfico Pizza e Rosca

remoto_contagem = df_limpo['proporcao_remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_emprego', 'proporcao_remoto']
fig = px.pie(
    remoto_contagem,
    names='tipo_emprego',
    values='proporcao_remoto',
    title='Proporção dos Tipos de Trabalho Remoto',
    hole=0.5
)

fig.update_traces(textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

# Calcula a média de salário por localização da empresa
df_salario_por_pais = df_limpo.groupby('localizacao_empresa')['salario_em_usd'].mean().reset_index()

# Classifica os dados pela média salarial em ordem decrescente para melhor visualização
df_salario_por_pais = df_salario_por_pais.sort_values(by='salario_em_usd', ascending=False)

# Cria o gráfico de barras usando Plotly Express
fig = px.bar(
    df_salario_por_pais.head(20), # Exibe os 20 principais países para melhor legibilidade
    x='localizacao_empresa',
    y='salario_em_usd',
    title='Média Salarial por Localização da Empresa (Top 20)',
    labels={
        'localizacao_empresa': 'Localização da Empresa',
        'salario_em_usd': 'Média Salarial Anual (USD)'
    },
    color='localizacao_empresa', # Colore as barras por país
    color_discrete_sequence=px.colors.qualitative.Plotly # Escolhe uma sequência de cores
)

# Atualiza o layout para melhor legibilidade
fig.update_layout(xaxis_title='País', yaxis_title='Média Salarial Anual (USD)')

# Exibe o gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #5 - Gráfico de Países

# %%
import pycountry
import plotly.express as px

def iso2_to_iso3(code):
    try:
        return pycountry.countries.get(alpha_2=code).alpha_3
    except:
        return None

df_limpo['residencia_iso3'] = df_limpo['residencia_funcionario'].apply(iso2_to_iso3)

df_ds = df_limpo[df_limpo['titulo_cargo'] == 'Data Scientist']
media_ds_pais = df_ds.groupby('residencia_iso3')['salario_em_usd'].mean().reset_index()

fig = px.choropleth(
    media_ds_pais,
    locations='residencia_iso3',
    color='salario_em_usd',
    color_continuous_scale='RdYlGn',
    title='Salário médio de Cientista de Dados por país',
    labels={'salario_em_usd': 'Salário médio (USD)', 'residencia_iso3': 'País'}
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
